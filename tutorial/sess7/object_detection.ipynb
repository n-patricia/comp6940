# %%
import cv2
import numpy as np
import os
import os.path as osp
import sys
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Subset, DataLoader
from torch.utils.data import Dataset

import torchvision
from torchvision import tv_tensors
from torchvision.io import read_image
from torchvision.ops.boxes import masks_to_boxes
from torchvision.transforms import v2 as T
from torchvision.transforms.v2 import functional as F
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
from torchvision.utils import draw_bounding_boxes, draw_segmentation_masks

import matplotlib.pyplot as plt

import utils
from engine import train_one_epoch, evaluate

# %% [markdown]
# # Data preparation

# %%
# !mkdir -p ./datasets/

# %%
# !wget https://www.cis.upenn.edu/~jshi/ped_html/PennFudanPed.zip -P ./datasets/
# Out:
# --2024-04-28 13:00:51--  https://www.cis.upenn.edu/~jshi/ped_html/PennFudanPed.zip
# Resolving www.cis.upenn.edu (www.cis.upenn.edu)... 158.130.69.163, 2607:f470:8:64:5ea5::d
# Connecting to www.cis.upenn.edu (www.cis.upenn.edu)|158.130.69.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53723336 (51M) [application/zip]
# Saving to: ‘PennFudanPed.zip’
#
# PennFudanPed.zip    100%[===================>]  51.23M   101MB/s    in 0.5s
#
# 2024-04-28 13:00:51 (101 MB/s) - ‘PennFudanPed.zip’ saved [53723336/53723336]
#
# --2024-04-28 13:00:51--  http://./
# Resolving . (.)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘.’
# FINISHED --2024-04-28 13:00:51--
# Total wall clock time: 0.6s
# Downloaded: 1 files, 51M in 0.5s (101 MB/s)

# %%
# !cd ./datasets

# %%
# !unzip PennFudanPed.zip
# Out:
# Archive:  ./PennFudanPed.zip
#    creating: ./datasets/PennFudanPed/
#   inflating: ./datasets/PennFudanPed/added-object-list.txt
#    creating: ./datasets/PennFudanPed/Annotation/
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00001.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00002.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00003.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00004.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00005.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00006.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00007.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00008.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00009.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00010.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00011.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00012.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00013.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00014.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00015.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00016.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00017.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00018.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00019.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00020.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00021.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00022.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00023.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00024.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00025.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00026.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00027.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00028.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00029.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00030.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00031.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00032.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00033.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00034.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00035.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00036.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00037.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00038.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00039.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00040.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00041.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00042.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00043.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00044.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00045.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00046.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00047.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00048.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00049.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00050.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00051.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00052.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00053.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00054.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00055.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00056.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00057.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00058.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00059.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00060.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00061.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00062.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00063.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00064.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00065.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00066.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00067.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00068.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00069.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00070.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00071.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00072.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00073.txt
#   inflating: ./datasets/PennFudanPed/Annotation/FudanPed00074.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00001.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00002.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00003.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00004.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00005.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00006.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00007.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00008.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00009.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00010.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00011.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00012.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00013.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00014.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00015.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00016.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00017.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00018.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00019.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00020.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00021.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00022.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00023.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00024.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00025.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00026.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00027.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00028.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00029.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00030.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00031.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00032.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00033.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00034.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00035.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00036.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00037.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00038.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00039.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00040.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00041.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00042.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00043.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00044.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00045.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00046.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00047.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00048.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00049.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00050.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00051.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00052.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00053.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00054.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00055.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00056.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00057.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00058.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00059.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00060.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00061.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00062.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00063.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00064.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00065.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00066.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00067.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00068.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00069.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00070.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00071.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00072.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00073.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00074.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00075.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00076.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00077.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00078.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00079.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00080.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00081.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00082.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00083.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00084.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00085.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00086.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00087.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00088.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00089.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00090.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00091.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00092.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00093.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00094.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00095.txt
#   inflating: ./datasets/PennFudanPed/Annotation/PennPed00096.txt
#    creating: ./datasets/PennFudanPed/PedMasks/
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00001_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00002_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00003_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00004_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00005_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00006_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00007_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00008_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00009_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00010_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00011_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00012_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00013_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00014_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/FudanPed00015_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00016_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00017_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/FudanPed00018_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00019_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00020_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00021_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00022_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00023_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00024_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00025_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00026_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00027_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/FudanPed00028_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00029_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00030_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00031_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00032_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00033_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00034_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00035_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00036_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00037_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00038_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00039_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00040_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00041_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00042_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00043_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00044_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00045_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00046_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00047_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00048_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00049_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00050_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00051_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00052_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00053_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00054_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00055_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00056_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00057_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00058_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00059_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00060_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00061_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00062_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00063_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00064_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00065_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00066_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00067_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00068_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00069_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00070_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00071_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00072_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00073_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/FudanPed00074_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00001_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00002_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00003_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00004_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00005_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00006_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00007_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00008_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00009_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00010_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00011_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00012_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00013_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00014_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00015_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00016_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00017_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00018_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00019_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00020_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00021_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00022_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00023_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00024_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00025_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00026_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00027_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00028_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00029_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00030_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00031_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00032_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00033_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00034_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00035_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00036_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00037_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00038_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00039_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00040_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00041_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00042_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00043_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00044_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00045_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00046_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00047_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00048_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00049_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00050_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00051_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00052_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/PennPed00053_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00054_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00055_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00056_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00057_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00058_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00059_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00060_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00061_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/PennPed00062_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00063_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00064_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00065_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/PennPed00066_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00067_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00068_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/PennPed00069_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/PennPed00070_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00071_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/PennPed00072_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00073_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/PennPed00074_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00075_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00076_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00077_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00078_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00079_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00080_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00081_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00082_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/PennPed00083_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/PennPed00084_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00085_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/PennPed00086_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00087_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00088_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/PennPed00089_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/PennPed00090_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00091_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00092_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00093_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00094_mask.png
#   inflating: ./datasets/PennFudanPed/PedMasks/PennPed00095_mask.png
#  extracting: ./datasets/PennFudanPed/PedMasks/PennPed00096_mask.png
#    creating: ./datasets/PennFudanPed/PNGImages/
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00001.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00002.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00003.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00004.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00005.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00006.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00007.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00008.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00009.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00010.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00011.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00012.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00013.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00014.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00015.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00016.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00017.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00018.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00019.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00020.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00021.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00022.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00023.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00024.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00025.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00026.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00027.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00028.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00029.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00030.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00031.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00032.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00033.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00034.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00035.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00036.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00037.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00038.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00039.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00040.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00041.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00042.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00043.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00044.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00045.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00046.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00047.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00048.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00049.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00050.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00051.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00052.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00053.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00054.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00055.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00056.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00057.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00058.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00059.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00060.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00061.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00062.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00063.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00064.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00065.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00066.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00067.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00068.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00069.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00070.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00071.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00072.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00073.png
#   inflating: ./datasets/PennFudanPed/PNGImages/FudanPed00074.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00001.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00002.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00003.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00004.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00005.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00006.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00007.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00008.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00009.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00010.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00011.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00012.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00013.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00014.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00015.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00016.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00017.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00018.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00019.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00020.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00021.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00022.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00023.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00024.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00025.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00026.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00027.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00028.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00029.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00030.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00031.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00032.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00033.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00034.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00035.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00036.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00037.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00038.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00039.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00040.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00041.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00042.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00043.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00044.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00045.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00046.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00047.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00048.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00049.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00050.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00051.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00052.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00053.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00054.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00055.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00056.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00057.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00058.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00059.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00060.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00061.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00062.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00063.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00064.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00065.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00066.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00067.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00068.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00069.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00070.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00071.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00072.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00073.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00074.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00075.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00076.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00077.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00078.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00079.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00080.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00081.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00082.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00083.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00084.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00085.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00086.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00087.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00088.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00089.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00090.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00091.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00092.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00093.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00094.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00095.png
#   inflating: ./datasets/PennFudanPed/PNGImages/PennPed00096.png
#   inflating: ./datasets/PennFudanPed/readme.txt

# %% [markdown]
# # Dataset

# %%
class PennFudanDataset(Dataset):
    def __init__(self, root, transforms):
        self.root = root
        self.transforms = transforms
        # load all image files, sorting them to
        # ensure that they are aligned
        self.imgs = list(sorted(os.listdir(osp.join(root, "PNGImages"))))
        self.masks = list(sorted(os.listdir(osp.join(root, "PedMasks"))))

    def __getitem__(self, idx):
        # load images and masks
        img_path = osp.join(self.root, "PNGImages", self.imgs[idx])
        mask_path = osp.join(self.root, "PedMasks", self.masks[idx])
        img = read_image(img_path)
        # mask is not converted into RGB,
        # because each color corresponds to a different instance
        # with 0 being background
        mask = read_image(mask_path)
        # instances are encoded as different colors
        obj_ids = torch.unique(mask)
        # first id is the background, so remove it
        obj_ids = obj_ids[1:]

        # split the color-encoded mask into a set
        # of binary masks
        masks = (mask == obj_ids[:, None, None]).to(dtype=torch.uint8)

        # # get bounding box coordinates for each mask
        num_objs = len(obj_ids)
        boxes = masks_to_boxes(masks)

        # convert everything into a torch.Tensor
        # there is only one class
        labels = torch.ones((num_objs,), dtype=torch.int64)

        image_id = idx
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)
        img = tv_tensors.Image(img)
        target = {}
        target["boxes"] = tv_tensors.BoundingBoxes(boxes, format="XYXY", canvas_size=F.get_size(img))
        target["labels"] = labels
        target["masks"] = tv_tensors.Mask(masks)
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        # database size
        return len(self.imgs)

# %% [markdown]
# # Model

# %%
# load a model pre-trained on COCO
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights="DEFAULT")
# replace the classifier with a new one
# 1 class (person) + background
num_classes = 2
# get number of input feature for the classifier
in_features = model.roi_heads.box_predictor.cls_score.in_features
# replace the pre-trained head with a new one
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:01<00:00, 139MB/s]

# %%
# load a pre-trained model for classification and
# return only the features
backbone = torchvision.models.mobilenet_v2(weights="DEFAULT").features
# FasterRCNN needs to know the number of output channels
# mobilenet_v2 has 1280 output channels
backbone.out_channels = 1280
# RPN generates 5x3 anchors per spatial location
# with 5 different sizes and 3 different aspect ratios
anchor_generator = AnchorGenerator(sizes=((32, 64, 128, 256, 512),),
                                   aspect_ratios=((0.5, 1.0, 2.0),))
# feature maps that we will use to perform
# the region of interest cropping,
# as well as the size of the crop after rescaling
roi_pooler = torchvision.ops.MultiScaleRoIAlign(featmap_names=['0'],
                                                output_size=7,
                                                sampling_ratio=2)
# put the pieces together inside a FasterRCNN model
model = FasterRCNN(backbone,
                   num_classes=num_classes,
                   rpn_anchor_generator=anchor_generator,
                   box_roi_pool=roi_pooler)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-7ebf99e0.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-7ebf99e0.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 71.5MB/s]

# %%
def get_model_instance_segmentation(num_classes):
    # load an instance segmentation model pre-trained on COCO
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(weights="DEFAULT")

    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    # now get the number of input features for the mask classifier
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256
    # and replace the mask predictor with a new one
    model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask,
                                                       hidden_layer,
                                                       num_classes)

    return model

# %%
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py")
# os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py")
# Out:
# 0

# %%
# data augmentation
def get_transform(train):
    transforms = []
    # transforms.append(T.PILToTensor())
    # transforms.append(T.ToDtype(torch.float))
    if train:
      transforms.append(T.RandomHorizontalFlip(0.5))
    transforms.append(T.ToDtype(torch.float, scale=True))
    transforms.append(T.ToPureTensor())
    return T.Compose(transforms)

# %% [markdown]
# # Training

# %%
# train on the GPU or on the CPU, if a GPU is not available
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# two classes only - background and person
num_classes = 2
# use train dataset and defined transformations
dataset = PennFudanDataset('/content/datasets/PennFudanPed', get_transform(train=True))
# use test dataset, no transformations
dataset_test = PennFudanDataset('/content/datasets/PennFudanPed', get_transform(train=False))

# split the dataset in train and test set
indices = torch.randperm(len(dataset)).tolist()
dataset = Subset(dataset, indices[:-50])
dataset_test = Subset(dataset_test, indices[-50:])

# define training data loaders
data_loader = DataLoader(
    dataset, batch_size=2, shuffle=True, num_workers=0,
    collate_fn=utils.collate_fn)

# define testing data loaders
data_loader_test = DataLoader(
    dataset_test, batch_size=1, shuffle=False, num_workers=0,
    collate_fn=utils.collate_fn)

# get the model using our helper function
model = get_model_instance_segmentation(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
# and a learning rate scheduler
lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# let's train it for 10 epochs
num_epochs = 10

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)

print("Finish training...")
# Out:
# Downloading: "https://download.pytorch.org/models/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth" to /root/.cache/torch/hub/checkpoints/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth
# 100%|██████████| 170M/170M [00:01<00:00, 142MB/s]
# Epoch: [0]  [ 0/60]  eta: 0:03:15  lr: 0.000090  loss: 4.1325 (4.1325)  loss_classifier: 1.0344 (1.0344)  loss_box_reg: 0.2712 (0.2712)  loss_mask: 2.7927 (2.7927)  loss_objectness: 0.0323 (0.0323)  loss_rpn_box_reg: 0.0019 (0.0019)  time: 3.2664  data: 0.0231  max mem: 2107
# Epoch: [0]  [10/60]  eta: 0:00:38  lr: 0.000936  loss: 1.9420 (2.3301)  loss_classifier: 0.6118 (0.5739)  loss_box_reg: 0.2401 (0.2562)  loss_mask: 0.9444 (1.4737)  loss_objectness: 0.0222 (0.0228)  loss_rpn_box_reg: 0.0030 (0.0034)  time: 0.7649  data: 0.0211  max mem: 3041
# Epoch: [0]  [20/60]  eta: 0:00:25  lr: 0.001783  loss: 0.7643 (1.5267)  loss_classifier: 0.1943 (0.3759)  loss_box_reg: 0.1951 (0.2241)  loss_mask: 0.3628 (0.9009)  loss_objectness: 0.0189 (0.0208)  loss_rpn_box_reg: 0.0030 (0.0050)  time: 0.5008  data: 0.0191  max mem: 3041
# Epoch: [0]  [30/60]  eta: 0:00:18  lr: 0.002629  loss: 0.6664 (1.2503)  loss_classifier: 0.1353 (0.2982)  loss_box_reg: 0.2121 (0.2473)  loss_mask: 0.2289 (0.6806)  loss_objectness: 0.0116 (0.0178)  loss_rpn_box_reg: 0.0075 (0.0064)  time: 0.5332  data: 0.0208  max mem: 3042
# Epoch: [0]  [40/60]  eta: 0:00:11  lr: 0.003476  loss: 0.6587 (1.0799)  loss_classifier: 0.1094 (0.2465)  loss_box_reg: 0.2388 (0.2493)  loss_mask: 0.2077 (0.5626)  loss_objectness: 0.0052 (0.0147)  loss_rpn_box_reg: 0.0077 (0.0068)  time: 0.5629  data: 0.0222  max mem: 3042
# Epoch: [0]  [50/60]  eta: 0:00:05  lr: 0.004323  loss: 0.4332 (0.9529)  loss_classifier: 0.0530 (0.2075)  loss_box_reg: 0.1808 (0.2369)  loss_mask: 0.2006 (0.4896)  loss_objectness: 0.0029 (0.0123)  loss_rpn_box_reg: 0.0051 (0.0066)  time: 0.5374  data: 0.0196  max mem: 3382
# Epoch: [0]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.3810 (0.8655)  loss_classifier: 0.0379 (0.1835)  loss_box_reg: 0.1517 (0.2249)  loss_mask: 0.1637 (0.4393)  loss_objectness: 0.0021 (0.0110)  loss_rpn_box_reg: 0.0041 (0.0068)  time: 0.5297  data: 0.0190  max mem: 3382
# Epoch: [0] Total time: 0:00:34 (0.5772 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:11  model_time: 0.1963 (0.1963)  evaluator_time: 0.0148 (0.0148)  time: 0.2239  data: 0.0120  max mem: 3382
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0960 (0.1082)  evaluator_time: 0.0046 (0.0078)  time: 0.1219  data: 0.0115  max mem: 3382
# Test: Total time: 0:00:06 (0.1286 s / it)
# Averaged stats: model_time: 0.0960 (0.1082)  evaluator_time: 0.0046 (0.0078)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.622
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.990
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.752
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.373
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.624
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.273
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.780
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.677
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.688
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.993
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.882
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.258
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.695
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.721
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.723
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.760
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.721
# Epoch: [1]  [ 0/60]  eta: 0:00:31  lr: 0.005000  loss: 0.4426 (0.4426)  loss_classifier: 0.0528 (0.0528)  loss_box_reg: 0.1370 (0.1370)  loss_mask: 0.2488 (0.2488)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0032 (0.0032)  time: 0.5248  data: 0.0267  max mem: 3382
# Epoch: [1]  [10/60]  eta: 0:00:26  lr: 0.005000  loss: 0.3316 (0.3358)  loss_classifier: 0.0369 (0.0412)  loss_box_reg: 0.1231 (0.1221)  loss_mask: 0.1599 (0.1661)  loss_objectness: 0.0008 (0.0018)  loss_rpn_box_reg: 0.0035 (0.0046)  time: 0.5371  data: 0.0203  max mem: 3382
# Epoch: [1]  [20/60]  eta: 0:00:22  lr: 0.005000  loss: 0.2895 (0.3184)  loss_classifier: 0.0304 (0.0398)  loss_box_reg: 0.1130 (0.1180)  loss_mask: 0.1514 (0.1539)  loss_objectness: 0.0008 (0.0017)  loss_rpn_box_reg: 0.0035 (0.0050)  time: 0.5556  data: 0.0198  max mem: 3382
# Epoch: [1]  [30/60]  eta: 0:00:16  lr: 0.005000  loss: 0.2782 (0.3032)  loss_classifier: 0.0330 (0.0395)  loss_box_reg: 0.0863 (0.1101)  loss_mask: 0.1327 (0.1470)  loss_objectness: 0.0008 (0.0018)  loss_rpn_box_reg: 0.0034 (0.0049)  time: 0.5670  data: 0.0192  max mem: 3382
# Epoch: [1]  [40/60]  eta: 0:00:11  lr: 0.005000  loss: 0.2782 (0.3029)  loss_classifier: 0.0364 (0.0408)  loss_box_reg: 0.0888 (0.1087)  loss_mask: 0.1349 (0.1464)  loss_objectness: 0.0007 (0.0018)  loss_rpn_box_reg: 0.0043 (0.0051)  time: 0.5651  data: 0.0196  max mem: 3382
# Epoch: [1]  [50/60]  eta: 0:00:05  lr: 0.005000  loss: 0.2688 (0.2955)  loss_classifier: 0.0393 (0.0406)  loss_box_reg: 0.0849 (0.1015)  loss_mask: 0.1416 (0.1465)  loss_objectness: 0.0008 (0.0019)  loss_rpn_box_reg: 0.0043 (0.0049)  time: 0.5795  data: 0.0211  max mem: 3785
# Epoch: [1]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.2438 (0.2866)  loss_classifier: 0.0307 (0.0389)  loss_box_reg: 0.0575 (0.0957)  loss_mask: 0.1296 (0.1456)  loss_objectness: 0.0005 (0.0017)  loss_rpn_box_reg: 0.0032 (0.0047)  time: 0.5827  data: 0.0201  max mem: 3785
# Epoch: [1] Total time: 0:00:34 (0.5686 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.1692 (0.1692)  evaluator_time: 0.0058 (0.0058)  time: 0.1872  data: 0.0114  max mem: 3785
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0957 (0.1061)  evaluator_time: 0.0034 (0.0049)  time: 0.1192  data: 0.0116  max mem: 3785
# Test: Total time: 0:00:06 (0.1234 s / it)
# Averaged stats: model_time: 0.0957 (0.1061)  evaluator_time: 0.0034 (0.0049)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.716
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.991
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.894
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.405
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.720
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.740
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.764
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.733
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.981
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.909
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.276
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.741
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.327
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.760
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.764
# Epoch: [2]  [ 0/60]  eta: 0:00:32  lr: 0.005000  loss: 0.1945 (0.1945)  loss_classifier: 0.0209 (0.0209)  loss_box_reg: 0.0525 (0.0525)  loss_mask: 0.1195 (0.1195)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0015 (0.0015)  time: 0.5483  data: 0.0204  max mem: 3785
# Epoch: [2]  [10/60]  eta: 0:00:29  lr: 0.005000  loss: 0.2235 (0.2363)  loss_classifier: 0.0278 (0.0348)  loss_box_reg: 0.0632 (0.0733)  loss_mask: 0.1243 (0.1241)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0017 (0.0035)  time: 0.5967  data: 0.0215  max mem: 3785
# Epoch: [2]  [20/60]  eta: 0:00:23  lr: 0.005000  loss: 0.2240 (0.2345)  loss_classifier: 0.0278 (0.0333)  loss_box_reg: 0.0632 (0.0680)  loss_mask: 0.1234 (0.1284)  loss_objectness: 0.0003 (0.0013)  loss_rpn_box_reg: 0.0034 (0.0036)  time: 0.5983  data: 0.0199  max mem: 3785
# Epoch: [2]  [30/60]  eta: 0:00:17  lr: 0.005000  loss: 0.2383 (0.2453)  loss_classifier: 0.0309 (0.0341)  loss_box_reg: 0.0646 (0.0738)  loss_mask: 0.1234 (0.1319)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0035 (0.0042)  time: 0.5970  data: 0.0198  max mem: 3785
# Epoch: [2]  [40/60]  eta: 0:00:11  lr: 0.005000  loss: 0.2252 (0.2385)  loss_classifier: 0.0321 (0.0333)  loss_box_reg: 0.0576 (0.0699)  loss_mask: 0.1260 (0.1299)  loss_objectness: 0.0004 (0.0015)  loss_rpn_box_reg: 0.0028 (0.0039)  time: 0.6026  data: 0.0206  max mem: 3785
# Epoch: [2]  [50/60]  eta: 0:00:06  lr: 0.005000  loss: 0.2252 (0.2405)  loss_classifier: 0.0306 (0.0334)  loss_box_reg: 0.0591 (0.0696)  loss_mask: 0.1319 (0.1317)  loss_objectness: 0.0005 (0.0016)  loss_rpn_box_reg: 0.0039 (0.0042)  time: 0.6071  data: 0.0199  max mem: 3785
# Epoch: [2]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.2073 (0.2324)  loss_classifier: 0.0259 (0.0324)  loss_box_reg: 0.0548 (0.0655)  loss_mask: 0.1122 (0.1290)  loss_objectness: 0.0005 (0.0015)  loss_rpn_box_reg: 0.0026 (0.0039)  time: 0.5717  data: 0.0184  max mem: 3785
# Epoch: [2] Total time: 0:00:35 (0.5918 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.1706 (0.1706)  evaluator_time: 0.0060 (0.0060)  time: 0.1890  data: 0.0116  max mem: 3785
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0981 (0.1077)  evaluator_time: 0.0031 (0.0043)  time: 0.1206  data: 0.0115  max mem: 3785
# Test: Total time: 0:00:06 (0.1244 s / it)
# Averaged stats: model_time: 0.0981 (0.1077)  evaluator_time: 0.0031 (0.0043)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.801
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.993
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.930
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.511
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.809
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.838
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.838
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.740
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.842
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.746
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.986
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.926
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.264
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.751
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.330
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.774
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.774
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.777
# Epoch: [3]  [ 0/60]  eta: 0:00:34  lr: 0.000500  loss: 0.1596 (0.1596)  loss_classifier: 0.0194 (0.0194)  loss_box_reg: 0.0283 (0.0283)  loss_mask: 0.1099 (0.1099)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0018 (0.0018)  time: 0.5726  data: 0.0229  max mem: 3785
# Epoch: [3]  [10/60]  eta: 0:00:29  lr: 0.000500  loss: 0.1626 (0.1874)  loss_classifier: 0.0239 (0.0242)  loss_box_reg: 0.0324 (0.0409)  loss_mask: 0.1128 (0.1179)  loss_objectness: 0.0004 (0.0007)  loss_rpn_box_reg: 0.0031 (0.0038)  time: 0.5850  data: 0.0202  max mem: 3785
# Epoch: [3]  [20/60]  eta: 0:00:23  lr: 0.000500  loss: 0.1836 (0.2034)  loss_classifier: 0.0265 (0.0291)  loss_box_reg: 0.0367 (0.0457)  loss_mask: 0.1189 (0.1243)  loss_objectness: 0.0005 (0.0010)  loss_rpn_box_reg: 0.0029 (0.0034)  time: 0.5798  data: 0.0197  max mem: 3785
# Epoch: [3]  [30/60]  eta: 0:00:17  lr: 0.000500  loss: 0.1911 (0.1969)  loss_classifier: 0.0295 (0.0290)  loss_box_reg: 0.0452 (0.0430)  loss_mask: 0.1229 (0.1209)  loss_objectness: 0.0005 (0.0010)  loss_rpn_box_reg: 0.0020 (0.0030)  time: 0.5725  data: 0.0192  max mem: 3785
# Epoch: [3]  [40/60]  eta: 0:00:11  lr: 0.000500  loss: 0.1755 (0.1933)  loss_classifier: 0.0251 (0.0282)  loss_box_reg: 0.0328 (0.0421)  loss_mask: 0.1048 (0.1192)  loss_objectness: 0.0004 (0.0010)  loss_rpn_box_reg: 0.0019 (0.0028)  time: 0.5621  data: 0.0180  max mem: 3785
# Epoch: [3]  [50/60]  eta: 0:00:05  lr: 0.000500  loss: 0.1818 (0.1937)  loss_classifier: 0.0230 (0.0281)  loss_box_reg: 0.0390 (0.0426)  loss_mask: 0.1088 (0.1192)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 0.5938  data: 0.0205  max mem: 3785
# Epoch: [3]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.1910 (0.1934)  loss_classifier: 0.0237 (0.0276)  loss_box_reg: 0.0432 (0.0424)  loss_mask: 0.1118 (0.1195)  loss_objectness: 0.0004 (0.0010)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 0.6076  data: 0.0211  max mem: 3785
# Epoch: [3] Total time: 0:00:34 (0.5831 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.1586 (0.1586)  evaluator_time: 0.0055 (0.0055)  time: 0.1763  data: 0.0116  max mem: 3785
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0978 (0.1072)  evaluator_time: 0.0031 (0.0045)  time: 0.1200  data: 0.0117  max mem: 3785
# Test: Total time: 0:00:06 (0.1242 s / it)
# Averaged stats: model_time: 0.0978 (0.1072)  evaluator_time: 0.0031 (0.0045)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.795
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.946
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.513
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.798
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.347
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.837
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.837
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.760
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.840
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.756
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.985
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.926
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.237
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.764
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.783
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.783
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.786
# Epoch: [4]  [ 0/60]  eta: 0:00:34  lr: 0.000500  loss: 0.2454 (0.2454)  loss_classifier: 0.0375 (0.0375)  loss_box_reg: 0.0580 (0.0580)  loss_mask: 0.1457 (0.1457)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0036 (0.0036)  time: 0.5694  data: 0.0221  max mem: 3785
# Epoch: [4]  [10/60]  eta: 0:00:29  lr: 0.000500  loss: 0.1769 (0.1932)  loss_classifier: 0.0235 (0.0258)  loss_box_reg: 0.0353 (0.0401)  loss_mask: 0.1220 (0.1231)  loss_objectness: 0.0010 (0.0011)  loss_rpn_box_reg: 0.0024 (0.0032)  time: 0.5879  data: 0.0189  max mem: 3785
# Epoch: [4]  [20/60]  eta: 0:00:22  lr: 0.000500  loss: 0.1724 (0.1891)  loss_classifier: 0.0235 (0.0270)  loss_box_reg: 0.0323 (0.0383)  loss_mask: 0.1061 (0.1197)  loss_objectness: 0.0006 (0.0013)  loss_rpn_box_reg: 0.0019 (0.0029)  time: 0.5701  data: 0.0192  max mem: 3785
# Epoch: [4]  [30/60]  eta: 0:00:17  lr: 0.000500  loss: 0.1667 (0.1889)  loss_classifier: 0.0259 (0.0264)  loss_box_reg: 0.0326 (0.0388)  loss_mask: 0.1088 (0.1199)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0019 (0.0027)  time: 0.5637  data: 0.0197  max mem: 3785
# Epoch: [4]  [40/60]  eta: 0:00:11  lr: 0.000500  loss: 0.1703 (0.1871)  loss_classifier: 0.0260 (0.0264)  loss_box_reg: 0.0371 (0.0388)  loss_mask: 0.1126 (0.1179)  loss_objectness: 0.0005 (0.0013)  loss_rpn_box_reg: 0.0027 (0.0028)  time: 0.5916  data: 0.0205  max mem: 3785
# Epoch: [4]  [50/60]  eta: 0:00:05  lr: 0.000500  loss: 0.1847 (0.1897)  loss_classifier: 0.0276 (0.0273)  loss_box_reg: 0.0428 (0.0408)  loss_mask: 0.1108 (0.1176)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0032 (0.0029)  time: 0.6113  data: 0.0212  max mem: 3785
# Epoch: [4]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.1648 (0.1869)  loss_classifier: 0.0243 (0.0269)  loss_box_reg: 0.0312 (0.0395)  loss_mask: 0.1083 (0.1165)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0032 (0.0029)  time: 0.5927  data: 0.0196  max mem: 3785
# Epoch: [4] Total time: 0:00:35 (0.5841 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.1681 (0.1681)  evaluator_time: 0.0049 (0.0049)  time: 0.1857  data: 0.0120  max mem: 3785
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0988 (0.1083)  evaluator_time: 0.0032 (0.0045)  time: 0.1207  data: 0.0116  max mem: 3785
# Test: Total time: 0:00:06 (0.1253 s / it)
# Averaged stats: model_time: 0.0988 (0.1083)  evaluator_time: 0.0032 (0.0045)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.813
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.946
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.509
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.817
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.348
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.852
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.852
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.780
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.855
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.755
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.984
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.935
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.764
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.783
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.783
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.787
# Epoch: [5]  [ 0/60]  eta: 0:00:30  lr: 0.000500  loss: 0.2203 (0.2203)  loss_classifier: 0.0262 (0.0262)  loss_box_reg: 0.0465 (0.0465)  loss_mask: 0.1441 (0.1441)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 0.5134  data: 0.0192  max mem: 3785
# Epoch: [5]  [10/60]  eta: 0:00:28  lr: 0.000500  loss: 0.1648 (0.1698)  loss_classifier: 0.0262 (0.0249)  loss_box_reg: 0.0271 (0.0305)  loss_mask: 0.1061 (0.1113)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0017 (0.0020)  time: 0.5665  data: 0.0202  max mem: 3785
# Epoch: [5]  [20/60]  eta: 0:00:23  lr: 0.000500  loss: 0.1652 (0.1889)  loss_classifier: 0.0221 (0.0248)  loss_box_reg: 0.0294 (0.0392)  loss_mask: 0.1076 (0.1201)  loss_objectness: 0.0005 (0.0022)  loss_rpn_box_reg: 0.0024 (0.0027)  time: 0.5973  data: 0.0205  max mem: 3785
# Epoch: [5]  [30/60]  eta: 0:00:17  lr: 0.000500  loss: 0.1664 (0.1827)  loss_classifier: 0.0195 (0.0234)  loss_box_reg: 0.0331 (0.0381)  loss_mask: 0.1144 (0.1167)  loss_objectness: 0.0005 (0.0018)  loss_rpn_box_reg: 0.0025 (0.0027)  time: 0.6103  data: 0.0190  max mem: 3785
# Epoch: [5]  [40/60]  eta: 0:00:11  lr: 0.000500  loss: 0.1770 (0.1870)  loss_classifier: 0.0210 (0.0250)  loss_box_reg: 0.0358 (0.0400)  loss_mask: 0.1028 (0.1175)  loss_objectness: 0.0007 (0.0017)  loss_rpn_box_reg: 0.0022 (0.0028)  time: 0.5866  data: 0.0195  max mem: 3785
# Epoch: [5]  [50/60]  eta: 0:00:05  lr: 0.000500  loss: 0.1822 (0.1844)  loss_classifier: 0.0253 (0.0250)  loss_box_reg: 0.0383 (0.0387)  loss_mask: 0.1034 (0.1166)  loss_objectness: 0.0005 (0.0015)  loss_rpn_box_reg: 0.0021 (0.0026)  time: 0.5912  data: 0.0203  max mem: 3785
# Epoch: [5]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.1560 (0.1811)  loss_classifier: 0.0218 (0.0248)  loss_box_reg: 0.0271 (0.0375)  loss_mask: 0.1016 (0.1147)  loss_objectness: 0.0003 (0.0015)  loss_rpn_box_reg: 0.0017 (0.0025)  time: 0.5942  data: 0.0188  max mem: 3785
# Epoch: [5] Total time: 0:00:35 (0.5919 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.1677 (0.1677)  evaluator_time: 0.0048 (0.0048)  time: 0.1852  data: 0.0120  max mem: 3785
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0975 (0.1076)  evaluator_time: 0.0029 (0.0043)  time: 0.1199  data: 0.0115  max mem: 3785
# Test: Total time: 0:00:06 (0.1243 s / it)
# Averaged stats: model_time: 0.0975 (0.1076)  evaluator_time: 0.0029 (0.0043)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.815
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.947
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.511
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.820
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.352
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.854
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.854
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.780
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.756
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.927
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.245
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.764
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.783
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.783
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.787
# Epoch: [6]  [ 0/60]  eta: 0:00:34  lr: 0.000050  loss: 0.1541 (0.1541)  loss_classifier: 0.0191 (0.0191)  loss_box_reg: 0.0207 (0.0207)  loss_mask: 0.1115 (0.1115)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 0.5801  data: 0.0164  max mem: 3785
# Epoch: [6]  [10/60]  eta: 0:00:31  lr: 0.000050  loss: 0.1718 (0.1879)  loss_classifier: 0.0221 (0.0269)  loss_box_reg: 0.0381 (0.0420)  loss_mask: 0.1115 (0.1147)  loss_objectness: 0.0006 (0.0012)  loss_rpn_box_reg: 0.0033 (0.0030)  time: 0.6244  data: 0.0218  max mem: 3785
# Epoch: [6]  [20/60]  eta: 0:00:24  lr: 0.000050  loss: 0.1718 (0.1895)  loss_classifier: 0.0225 (0.0285)  loss_box_reg: 0.0344 (0.0408)  loss_mask: 0.1099 (0.1162)  loss_objectness: 0.0006 (0.0011)  loss_rpn_box_reg: 0.0033 (0.0029)  time: 0.6216  data: 0.0217  max mem: 3785
# Epoch: [6]  [30/60]  eta: 0:00:18  lr: 0.000050  loss: 0.1689 (0.1846)  loss_classifier: 0.0203 (0.0266)  loss_box_reg: 0.0265 (0.0380)  loss_mask: 0.1092 (0.1162)  loss_objectness: 0.0002 (0.0012)  loss_rpn_box_reg: 0.0019 (0.0026)  time: 0.5928  data: 0.0197  max mem: 3785
# Epoch: [6]  [40/60]  eta: 0:00:12  lr: 0.000050  loss: 0.1733 (0.1855)  loss_classifier: 0.0215 (0.0265)  loss_box_reg: 0.0299 (0.0384)  loss_mask: 0.1092 (0.1167)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0022 (0.0027)  time: 0.5837  data: 0.0193  max mem: 3785
# Epoch: [6]  [50/60]  eta: 0:00:06  lr: 0.000050  loss: 0.1726 (0.1810)  loss_classifier: 0.0219 (0.0257)  loss_box_reg: 0.0343 (0.0369)  loss_mask: 0.1013 (0.1147)  loss_objectness: 0.0003 (0.0013)  loss_rpn_box_reg: 0.0018 (0.0025)  time: 0.5955  data: 0.0197  max mem: 3785
# Epoch: [6]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.1656 (0.1796)  loss_classifier: 0.0217 (0.0258)  loss_box_reg: 0.0308 (0.0359)  loss_mask: 0.1046 (0.1143)  loss_objectness: 0.0004 (0.0013)  loss_rpn_box_reg: 0.0017 (0.0024)  time: 0.5899  data: 0.0192  max mem: 3785
# Epoch: [6] Total time: 0:00:35 (0.5972 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.1596 (0.1596)  evaluator_time: 0.0049 (0.0049)  time: 0.1770  data: 0.0117  max mem: 3785
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0997 (0.1077)  evaluator_time: 0.0030 (0.0044)  time: 0.1209  data: 0.0118  max mem: 3785
# Test: Total time: 0:00:06 (0.1247 s / it)
# Averaged stats: model_time: 0.0997 (0.1077)  evaluator_time: 0.0030 (0.0044)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.814
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.946
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.511
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.819
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.854
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.854
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.780
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.857
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.758
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.994
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.936
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.245
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.767
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.333
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.784
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.786
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.789
# Epoch: [7]  [ 0/60]  eta: 0:00:44  lr: 0.000050  loss: 0.1396 (0.1396)  loss_classifier: 0.0092 (0.0092)  loss_box_reg: 0.0217 (0.0217)  loss_mask: 0.1064 (0.1064)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0018 (0.0018)  time: 0.7346  data: 0.0170  max mem: 3785
# Epoch: [7]  [10/60]  eta: 0:00:30  lr: 0.000050  loss: 0.1557 (0.1646)  loss_classifier: 0.0205 (0.0213)  loss_box_reg: 0.0239 (0.0283)  loss_mask: 0.1064 (0.1119)  loss_objectness: 0.0005 (0.0006)  loss_rpn_box_reg: 0.0019 (0.0025)  time: 0.6062  data: 0.0186  max mem: 3785
# Epoch: [7]  [20/60]  eta: 0:00:23  lr: 0.000050  loss: 0.1557 (0.1682)  loss_classifier: 0.0205 (0.0214)  loss_box_reg: 0.0239 (0.0299)  loss_mask: 0.1056 (0.1126)  loss_objectness: 0.0005 (0.0020)  loss_rpn_box_reg: 0.0018 (0.0023)  time: 0.5735  data: 0.0194  max mem: 3785
# Epoch: [7]  [30/60]  eta: 0:00:17  lr: 0.000050  loss: 0.1677 (0.1739)  loss_classifier: 0.0226 (0.0230)  loss_box_reg: 0.0301 (0.0321)  loss_mask: 0.1109 (0.1148)  loss_objectness: 0.0006 (0.0015)  loss_rpn_box_reg: 0.0019 (0.0025)  time: 0.5757  data: 0.0199  max mem: 3785
# Epoch: [7]  [40/60]  eta: 0:00:11  lr: 0.000050  loss: 0.1735 (0.1762)  loss_classifier: 0.0274 (0.0243)  loss_box_reg: 0.0338 (0.0341)  loss_mask: 0.1140 (0.1140)  loss_objectness: 0.0004 (0.0015)  loss_rpn_box_reg: 0.0020 (0.0024)  time: 0.5915  data: 0.0195  max mem: 3785
# Epoch: [7]  [50/60]  eta: 0:00:05  lr: 0.000050  loss: 0.1829 (0.1812)  loss_classifier: 0.0284 (0.0258)  loss_box_reg: 0.0384 (0.0364)  loss_mask: 0.1147 (0.1151)  loss_objectness: 0.0004 (0.0014)  loss_rpn_box_reg: 0.0021 (0.0025)  time: 0.6080  data: 0.0205  max mem: 3785
# Epoch: [7]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.1568 (0.1771)  loss_classifier: 0.0251 (0.0251)  loss_box_reg: 0.0340 (0.0347)  loss_mask: 0.1106 (0.1137)  loss_objectness: 0.0002 (0.0012)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 0.6179  data: 0.0199  max mem: 3785
# Epoch: [7] Total time: 0:00:35 (0.5955 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.1646 (0.1646)  evaluator_time: 0.0050 (0.0050)  time: 0.1819  data: 0.0116  max mem: 3785
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0996 (0.1082)  evaluator_time: 0.0033 (0.0044)  time: 0.1207  data: 0.0116  max mem: 3785
# Test: Total time: 0:00:06 (0.1250 s / it)
# Averaged stats: model_time: 0.0996 (0.1082)  evaluator_time: 0.0033 (0.0044)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.812
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.946
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.511
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.816
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.853
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.853
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.780
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.856
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.755
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.936
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.241
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.333
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.781
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.783
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.786
# Epoch: [8]  [ 0/60]  eta: 0:00:27  lr: 0.000050  loss: 0.1131 (0.1131)  loss_classifier: 0.0121 (0.0121)  loss_box_reg: 0.0098 (0.0098)  loss_mask: 0.0898 (0.0898)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0010 (0.0010)  time: 0.4591  data: 0.0151  max mem: 3785
# Epoch: [8]  [10/60]  eta: 0:00:28  lr: 0.000050  loss: 0.1791 (0.1845)  loss_classifier: 0.0292 (0.0271)  loss_box_reg: 0.0309 (0.0365)  loss_mask: 0.1031 (0.1164)  loss_objectness: 0.0004 (0.0010)  loss_rpn_box_reg: 0.0034 (0.0034)  time: 0.5789  data: 0.0199  max mem: 3785
# Epoch: [8]  [20/60]  eta: 0:00:22  lr: 0.000050  loss: 0.1706 (0.1799)  loss_classifier: 0.0218 (0.0240)  loss_box_reg: 0.0302 (0.0346)  loss_mask: 0.1020 (0.1174)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0020 (0.0028)  time: 0.5756  data: 0.0190  max mem: 3785
# Epoch: [8]  [30/60]  eta: 0:00:16  lr: 0.000050  loss: 0.1547 (0.1729)  loss_classifier: 0.0204 (0.0230)  loss_box_reg: 0.0296 (0.0325)  loss_mask: 0.1019 (0.1139)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0016 (0.0024)  time: 0.5553  data: 0.0179  max mem: 3785
# Epoch: [8]  [40/60]  eta: 0:00:11  lr: 0.000050  loss: 0.1669 (0.1772)  loss_classifier: 0.0216 (0.0245)  loss_box_reg: 0.0310 (0.0342)  loss_mask: 0.1102 (0.1148)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0018 (0.0025)  time: 0.5990  data: 0.0208  max mem: 3785
# Epoch: [8]  [50/60]  eta: 0:00:05  lr: 0.000050  loss: 0.1714 (0.1787)  loss_classifier: 0.0265 (0.0253)  loss_box_reg: 0.0303 (0.0348)  loss_mask: 0.1138 (0.1147)  loss_objectness: 0.0003 (0.0015)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 0.6093  data: 0.0215  max mem: 3785
# Epoch: [8]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.1676 (0.1791)  loss_classifier: 0.0244 (0.0254)  loss_box_reg: 0.0291 (0.0354)  loss_mask: 0.1102 (0.1144)  loss_objectness: 0.0005 (0.0014)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 0.6155  data: 0.0201  max mem: 3785
# Epoch: [8] Total time: 0:00:35 (0.5925 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.1640 (0.1640)  evaluator_time: 0.0048 (0.0048)  time: 0.1821  data: 0.0125  max mem: 3785
# Test:  [49/50]  eta: 0:00:00  model_time: 0.1000 (0.1086)  evaluator_time: 0.0031 (0.0043)  time: 0.1211  data: 0.0115  max mem: 3785
# Test: Total time: 0:00:06 (0.1252 s / it)
# Averaged stats: model_time: 0.1000 (0.1086)  evaluator_time: 0.0031 (0.0043)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.810
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.947
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.510
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.815
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.355
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.760
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.854
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.755
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.936
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.245
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.781
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.783
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.720
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.786
# Epoch: [9]  [ 0/60]  eta: 0:00:33  lr: 0.000005  loss: 0.1342 (0.1342)  loss_classifier: 0.0111 (0.0111)  loss_box_reg: 0.0094 (0.0094)  loss_mask: 0.1104 (0.1104)  loss_objectness: 0.0022 (0.0022)  loss_rpn_box_reg: 0.0011 (0.0011)  time: 0.5605  data: 0.0143  max mem: 3785
# Epoch: [9]  [10/60]  eta: 0:00:29  lr: 0.000005  loss: 0.1957 (0.1808)  loss_classifier: 0.0280 (0.0276)  loss_box_reg: 0.0333 (0.0335)  loss_mask: 0.1216 (0.1164)  loss_objectness: 0.0009 (0.0012)  loss_rpn_box_reg: 0.0017 (0.0022)  time: 0.5880  data: 0.0181  max mem: 3785
# Epoch: [9]  [20/60]  eta: 0:00:24  lr: 0.000005  loss: 0.1677 (0.1759)  loss_classifier: 0.0232 (0.0263)  loss_box_reg: 0.0329 (0.0348)  loss_mask: 0.1052 (0.1114)  loss_objectness: 0.0008 (0.0011)  loss_rpn_box_reg: 0.0017 (0.0023)  time: 0.6135  data: 0.0187  max mem: 3785
# Epoch: [9]  [30/60]  eta: 0:00:18  lr: 0.000005  loss: 0.1677 (0.1820)  loss_classifier: 0.0243 (0.0274)  loss_box_reg: 0.0351 (0.0372)  loss_mask: 0.1066 (0.1138)  loss_objectness: 0.0007 (0.0012)  loss_rpn_box_reg: 0.0019 (0.0024)  time: 0.6248  data: 0.0206  max mem: 3785
# Epoch: [9]  [40/60]  eta: 0:00:11  lr: 0.000005  loss: 0.1491 (0.1756)  loss_classifier: 0.0232 (0.0260)  loss_box_reg: 0.0247 (0.0350)  loss_mask: 0.1054 (0.1112)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0018 (0.0023)  time: 0.5800  data: 0.0200  max mem: 3785
# Epoch: [9]  [50/60]  eta: 0:00:05  lr: 0.000005  loss: 0.1491 (0.1813)  loss_classifier: 0.0200 (0.0266)  loss_box_reg: 0.0235 (0.0369)  loss_mask: 0.1054 (0.1141)  loss_objectness: 0.0005 (0.0011)  loss_rpn_box_reg: 0.0032 (0.0026)  time: 0.5748  data: 0.0196  max mem: 3785
# Epoch: [9]  [59/60]  eta: 0:00:00  lr: 0.000005  loss: 0.1759 (0.1786)  loss_classifier: 0.0216 (0.0259)  loss_box_reg: 0.0315 (0.0356)  loss_mask: 0.1119 (0.1136)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0027 (0.0025)  time: 0.5723  data: 0.0194  max mem: 3785
# Epoch: [9] Total time: 0:00:35 (0.5888 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.1688 (0.1688)  evaluator_time: 0.0050 (0.0050)  time: 0.1862  data: 0.0116  max mem: 3785
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0997 (0.1092)  evaluator_time: 0.0032 (0.0043)  time: 0.1227  data: 0.0117  max mem: 3785
# Test: Total time: 0:00:06 (0.1259 s / it)
# Averaged stats: model_time: 0.0997 (0.1092)  evaluator_time: 0.0032 (0.0043)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.810
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.946
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.511
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.355
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.851
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.851
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.780
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.854
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.756
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.935
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.245
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.764
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.333
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.782
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.784
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.720
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.787
# Finish training...

# %% [markdown]
# # Inference

# %%
image = read_image("/content/datasets/PennFudanPed/PNGImages/PennPed00034.png")
eval_transform = get_transform(train=False)

# %%
# no gradient computation
model.eval()
with torch.no_grad():
  x = eval_transform(image)
  # convert RGBA -> RGB and move to device
  x = x[:3, ...].to(device)
  predictions = model([x,])
  pred = predictions[0]

# %%
image = (255.0 * (image-image.min()) / (image.max()-image.min())).to(torch.uint8)
image = image[:3, ...]
pred_labels = [f"pedestrian: {score:.3f}" for label, score in zip(pred["labels"],pred["scores"])]
pred_boxes = pred["boxes"].long()
output_image = draw_bounding_boxes(image, pred_boxes, pred_labels, colors="red")
masks = (pred["masks"] > 0.7).squeeze(1)
output_image = draw_segmentation_masks(output_image, masks, alpha=0.5, colors="blue")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-0fdec91132fb> in <cell line: 6>()
#       4 pred_boxes = pred["boxes"].long()
#       5 output_image = draw_bounding_boxes(image, pred_boxes, pred_labels, colors="red")
# ----> 6 masks = (pred["mask"]>0.7).squeeze(1)
#       7 output_image = draw_segmentation_masks(output_image, masks, alpha=0.5, colors="blue")
#
# KeyError: 'mask'

# %%
pred.keys()
# Out:
# tensor([0.5509, 0.5490, 0.5449, 0.5404, 0.5395, 0.5394, 0.5390, 0.5389, 0.5387,
#         0.5378, 0.5377, 0.5370, 0.5367, 0.5364, 0.5362, 0.5360, 0.5345, 0.5344,
#         0.5340, 0.5340, 0.5337, 0.5336, 0.5335, 0.5323, 0.5321, 0.5320, 0.5319,
#         0.5316, 0.5316, 0.5316, 0.5315, 0.5302, 0.5301, 0.5301, 0.5299, 0.5297,
#         0.5297, 0.5294, 0.5291, 0.5290, 0.5281, 0.5280, 0.5278, 0.5278, 0.5276,
#         0.5275, 0.5273, 0.5269, 0.5267, 0.5266, 0.5263, 0.5260, 0.5259, 0.5255,
#         0.5254, 0.5253, 0.5253, 0.5252, 0.5251, 0.5246, 0.5242, 0.5241, 0.5241,
#         0.5241, 0.5239, 0.5239, 0.5237, 0.5236, 0.5236, 0.5236, 0.5234, 0.5233,
#         0.5232, 0.5232, 0.5232, 0.5230, 0.5230, 0.5229, 0.5228, 0.5227, 0.5224,
#         0.5224, 0.5223, 0.5223, 0.5223, 0.5223, 0.5222, 0.5221, 0.5221, 0.5220,
#         0.5220, 0.5220, 0.5219, 0.5218, 0.5218, 0.5216, 0.5216, 0.5215, 0.5215,
#         0.5215], device='cuda:0')
